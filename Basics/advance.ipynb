# %%
x = int(1)   # x will be 1
y = int(2.8) # y will be 2
z = int("3") # z will be 3

# %%
list1 = ["apple", "banana", "cherry"]
list2 = [True, False, False]
list3 = [1, 5, 7, 9, 3]
list4 = list((1, 5, 7, 9, 3))
