# %%
print("'hello world'")
# Out:
# 'hello world'

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# Data Structure --List--
tech_stack = ["Laravel", "React", "Python", "MySQL"]

tech_stack.append("Pandas") 

tech_stack.insert(1, "PostgreSQL") 

# (Slicing) 
top_two = tech_stack[0:2] 

print(f"Complete Stack: {tech_stack}")
print(f"Top 2 Tech: {top_two}")
# Out:
# Complete Stack: ['Laravel', 'PostgreSQL', 'React', 'Python', 'MySQL', 'Pandas']
# Top 2 Tech: ['Laravel', 'PostgreSQL']

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             


# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
p1 = MyClass()
p2 = MyClass()
p3 = MyClass()

print(p1.x)
print(p2.x)
print(p3.x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 p1 = MyClass()
#       2 p2 = MyClass()
#       3 p3 = MyClass()
#       4
#
# NameError: name 'MyClass' is not defined

# %%
def isfloat(num):
    try:
        float(num)
        return True
    except ValueError:
        return False

print(isfloat('s12'))
print(isfloat('1.123'))
# Out:
# False
# True

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
# Out:
# Project: E-commerce API (v2.0)
# Lead: Zaky, Assistant: naem

# %%
# 1. Variable Declaretion
project_name = "E-commerce API" 
version = 2.0                  
is_active = True                
developer_count = 5             

# Same line 
lead, assistant = "Zaky", "naem"

print(f"Project: {project_name} (v{version})")
print(f"Lead: {lead}, Assistant: {assistant}")
